# %% [markdown]
# **Generating images from trained models**

# %% [markdown]
# Gnerating 300 images for each class 0 or 1 using Stylegan2

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import json
from distutils.dir_util import copy_tree
import shutil

# %%
#Uninstall new JAX
# !pip uninstall jax jaxlib -y
#GPU frontend
# !pip install "jax[cuda11_cudnn805]==0.3.10" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
#CPU frontend
#!pip install jax[cpu]==0.3.10
#Downgrade Pytorch
# !pip uninstall torch torchvision -y
# !pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install timm==0.4.12 ftfy==6.1.1 ninja==1.10.2
# Out:
# Found existing installation: jax 0.3.14
# Uninstalling jax-0.3.14:
#   Successfully uninstalled jax-0.3.14
# Found existing installation: jaxlib 0.3.14+cuda11.cudnn805
# Uninstalling jaxlib-0.3.14+cuda11.cudnn805:
#   Successfully uninstalled jaxlib-0.3.14+cuda11.cudnn805
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# ...
#      |████████████████████████████████| 939 kB 13.8 MB/s
# ...
#      |████████████████████████████████| 175.7 MB 7.9 kB/s
# ...
#   Created wheel for jax: filename=jax-0.3.10-py3-none-any.whl size=1088066 sha256=bc3f54ffdde39f10f09330927d0adf13b614ca4dfb00f6d8a7928b79df08332f
#   Stored in directory: /root/.cache/pip/wheels/1c/05/23/36730377cd7311156f1e5eb5e7c683d5cdac1654658c095cc5
# Successfully built jax
# ...
# Found existing installation: torch 1.12.1+cu113
# Uninstalling torch-1.12.1+cu113:
#   Successfully uninstalled torch-1.12.1+cu113
# ...

# %%
# !pip install setuptools==59.5.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 952 kB 16.6 MB/s
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# ...

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git stylegan
# %cd stylegan
#!pip install ninia
# Out:
# Cloning into 'stylegan'...
# remote: Enumerating objects: 128, done.
# remote: Total 128 (delta 0), reused 0 (delta 0), pack-reused 128
# Receiving objects: 100% (128/128), 1.12 MiB | 24.95 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# /content/stylegan

# %%
# !python /content/stylegan/generate.py --network /content/drive/MyDrive/Disso/trained_models/Stylegan2/outputs/00001-data-cond-auto1-kimg1000-noaug/network-snapshot-001000.pkl --seeds 0-300 --class 0 --outdir /content/drive/MyDrive/Disso/trained_models/styegan_2_generated_images
# Out:
# Loading networks from "/content/drive/MyDrive/Disso/trained_models/Stylegan2/outputs/00001-data-cond-auto1-kimg1000-noaug/network-snapshot-001000.pkl"...
# Generating image for seed 0 (0/301) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 1 (1/301) ...
# Generating image for seed 2 (2/301) ...
# Generating image for seed 3 (3/301) ...
# Generating image for seed 4 (4/301) ...
# Generating image for seed 5 (5/301) ...
# Generating image for seed 6 (6/301) ...
# Generating image for seed 7 (7/301) ...
# Generating image for seed 8 (8/301) ...
# Generating image for seed 9 (9/301) ...
# Generating image for seed 10 (10/301) ...
# Generating image for seed 11 (11/301) ...
# Generating image for seed 12 (12/301) ...
# Generating image for seed 13 (13/301) ...
# Generating image for seed 14 (14/301) ...
# Generating image for seed 15 (15/301) ...
# Generating image for seed 16 (16/301) ...
# ...

# %%
# !python /content/stylegan/generate.py --network /content/drive/MyDrive/Disso/trained_models/Stylegan2/outputs/00001-data-cond-auto1-kimg1000-noaug/network-snapshot-001000.pkl --seeds 0-300 --class 1 --outdir /content/drive/MyDrive/Disso/trained_models/generated_images/class_1_generated_images
# Out:
# Loading networks from "/content/drive/MyDrive/Disso/trained_models/Stylegan2/outputs/00001-data-cond-auto1-kimg1000-noaug/network-snapshot-001000.pkl"...
# Generating image for seed 0 (0/301) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 1 (1/301) ...
# Generating image for seed 2 (2/301) ...
# Generating image for seed 3 (3/301) ...
# Generating image for seed 4 (4/301) ...
# Generating image for seed 5 (5/301) ...
# Generating image for seed 6 (6/301) ...
# Generating image for seed 7 (7/301) ...
# Generating image for seed 8 (8/301) ...
# Generating image for seed 9 (9/301) ...
# Generating image for seed 10 (10/301) ...
# Generating image for seed 11 (11/301) ...
# Generating image for seed 12 (12/301) ...
# Generating image for seed 13 (13/301) ...
# Generating image for seed 14 (14/301) ...
# Generating image for seed 15 (15/301) ...
# Generating image for seed 16 (16/301) ...
# ...
